# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import NoSuchElementException

from bs4 import BeautifulSoup
import requests

import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %% [markdown]
# ### Scraping For Dallas, Texas

# %%
#opening the rentberry Austin,Tx page on automated chrome browser
driver = webdriver.Chrome()
driver.get('https://rentberry.com/apartments/s/dallas-tx')
time.sleep(2)

# %%
rent_URL = []
rent_Price = []

# %%
# to scrap URL of 66 pages
start = 0
end = 40

for page in range(start,end):
    url_tags= driver.find_elements(By.XPATH,'//a[@class="property-card-bottom-address__text link-ghost font-xs one-line-string"]')
    price = driver.find_elements(By.XPATH,'//rb-property-card-bottom[@class="property-card__bottom"]/div/div/rb-property-card-price/div/p')
   
    for _ in range(100):
        driver.execute_script("window.scrollBy(0,1000)")
        
    for t in url_tags:
        rent_URL.append(t.get_attribute('href'))
    for a in price:
        rent_Price.append(a.text)
        
    next_page = driver.find_element(By.XPATH,'//span[@class="pagination-arrow-next"]')
    next_page.click()
 
    time.sleep(5)

# %%
print(len(rent_URL),len(rent_Price))
# Out:
# 880 880

# %%
rent_Pets = []
rent_Area = []
rent_Address = []
rent_Deposit = []
rent_Beds = []
rent_Bathroom = []
rent_Washer_Dryer =[]
rent_AC = []
rent_Parking=[]
rent_Fireplace=[]
rent_Dishwasher=[]
rent_Floors=[]
rent_Roofdeck=[]
rent_Storage=[]

# %%
for t in rent_URL[751:]:
    driver.get(t)
    time.sleep(5)
    
    
    try:
        add = driver.find_element(By.XPATH,'/html/body/rb-core/div/rb-property/div/rb-property-main-info/section/div/div/rb-property-data/div/h4/span/span')
        rent_Address.append(add.text)
    except NoSuchElementException:
        rent_Address.append('np.nan')
        
    try:
        bed = driver.find_element(By.XPATH,"//*[contains(@class,'bedrooms')]")
        rent_Beds.append(bed.text)
    except NoSuchElementException:
        rent_Beds.append('np.nan') 
        
    try:
        bath = driver.find_element(By.XPATH,"//*[contains(@class,'bathrooms')]")
        rent_Bathroom.append(bath.text)
    except NoSuchElementException:
        rent_Bathroom.append('np.nan') 
        
    try:
        sqft = driver.find_element(By.XPATH,"//*[contains(@class,'space')]")
        rent_Area.append(sqft.text)
    except NoSuchElementException:
        rent_Area.append('np.nan')
        
    try:
        pets = driver.find_element(By.XPATH,"//*[contains(@class,'dog-icon facilities-param-icon')]" or "//*[contains(@class,'cat-icon facilities-param-icon')]")
        rent_Pets.append('Yes')
    except NoSuchElementException:
        rent_Pets.append('No')
        
    try:
        adv = driver.find_element(By.XPATH,'/html/body/rb-core/div/rb-property/div/div[2]/div/rb-apply-block/div/div/rb-button-square/button/span/span[2]/span[1]')
        rent_Deposit.append(adv.text.replace("Apply for $",''))
    except NoSuchElementException:
        rent_Deposit.append('np.nan')
        
    try:
        was = driver.find_element(By.XPATH, "//*[contains(@class,'icon washerUnit')]")
        rent_Washer_Dryer.append('Yes')
    except NoSuchElementException:
        rent_Washer_Dryer.append('No')   
        
    try:
        ac = driver.find_element(By.XPATH,"//*[contains(@class,'airConditioning icon')]")
        rent_AC.append('Yes')
    except NoSuchElementException:
        rent_AC.append('No')
       
    try:
        park = driver.find_element(By.XPATH,"//*[contains(@class,'icon parking')]")
        rent_Parking.append('Yes')
    except NoSuchElementException:
        rent_Parking.append('No') 

    try:
        dish = driver.find_element(By.XPATH,"//*[contains(@class,'dishwasher icon')]")
        rent_Dishwasher.append('Yes')
    except NoSuchElementException: 
        rent_Dishwasher.append('No')
    try:
        hard = driver.find_element(By.XPATH,"//*[contains(@class,'hardwoodFloors icon')]")
        rent_Floors.append('Yes')
    except NoSuchElementException:
        rent_Floors.append('No')
        
    try:
        roof = driver.find_element(By.XPATH,"//*[contains(@class,'icon roofDeck')]")
        rent_Roofdeck.append('Yes')  
    except NoSuchElementException:
        rent_Roofdeck.append('No')
        
    try:
        store = driver.find_element(By.XPATH, "//*[contains(@class,'icon storage')]")
        rent_Storage.append('Yes')
    except NoSuchElementException: 
        rent_Storage.append('No')
                    
    try:
        fire = driver.find_element(By.XPATH, "//*[contains(@class,'fireplace icon')]")
        rent_Fireplace.append('Yes')
    except NoSuchElementException:  
        rent_Fireplace.append('No')

# %%
print(len(rent_URL), len(rent_Price),len(rent_Address),len(rent_Bathroom),len(rent_Beds),len(rent_Area),len(rent_Pets),len(rent_Deposit),len(rent_AC),len(rent_Washer_Dryer),len(rent_Parking),len(rent_Dishwasher),len(rent_Floors),len(rent_Roofdeck),len(rent_Storage), len(rent_Fireplace))
# Out:
# 880 880 879 879 879 879 879 879 879 879 879 879 879 879 879 879

# %%
dallas = pd.DataFrame({'URL':rent_URL[:879],'Address':rent_Address[:879],'Rental Price':rent_Price[:879],'Deposit':rent_Deposit[:879],
                      'Bathroom':rent_Bathroom[:879],'Bedroom':rent_Beds[:879],'Rental Area':rent_Area[:879],'Pets':rent_Pets[:879],
                      'AC':rent_AC[:879],'Washer_Dryer':rent_Washer_Dryer[:879],'Parking':rent_Parking[:879],'Dishwasher':rent_Dishwasher[:879],
                      'Floors':rent_Floors[:879],'Roofdeck':rent_Roofdeck[:879],'Storage':rent_Storage[:879],'Fireplace':rent_Fireplace[:879]})
dallas
# Out:
#                                                    URL  \
# 0    https://rentberry.com/houses/111638657-five-br...
# 1    https://rentberry.com/houses/109702755-five-br...
# 2    https://rentberry.com/houses/117440948-four-br...
# 3    https://rentberry.com/houses/117440768-three-b...
# 4    https://rentberry.com/houses/116550845-four-br...
# ..                                                 ...
# 874  https://rentberry.com/houses/98277630-three-br...
# 875  https://rentberry.com/houses/96922820-one-br-d...
# 876  https://rentberry.com/apartments/98805585-two-...
# 877  https://rentberry.com/houses/115930970-four-br...
# 878  https://rentberry.com/houses/90098599-three-br...
#
#                                                Address Rental Price Deposit  \
# 0                                         7132 Hunt Ln       $8,750   8,750
# 1                                     4713 Highgate Ln      $10,950  10,950
# 2          1466 Plummer Drive, Rockwall, TX 75087, USA       $4,000   4,000
# 3    2647 Valley Glen Drive, Richardson, TX 75080, USA       $3,400   3,400
# 4              3814 Eaton Drive, Dallas, TX 75220, USA       $8,000   8,000
# ..                                                 ...          ...     ...
# 874                                         Dallas, TX       $6,990  np.nan
# 875                                         Dallas, TX       $2,760  np.nan
# 876        5673 St. Thomas Drive, Plano, TX 75094, USA       $3,720   3,950
# 877  2055 Dripping Springs Drive, Kaufman County, T...       $3,950   2,407
# 878  4723 Breckinridge Boulevard, Richardson, TX 75...       $2,407   3,800
#
#     Bathroom Bedroom Rental Area Pets   AC Washer_Dryer Parking Dishwasher  \
# 0       2.5       5       2,910   Yes  Yes           No      No        Yes
# 1       2.5       5       2,747   Yes  Yes           No      No        Yes
# 2         3       4       3,030    No   No           No      No         No
# 3         2       3       2,290    No   No           No      No         No
# 4       4.5       4       4,067    No   No           No      No         No
# ..       ...     ...         ...  ...  ...          ...     ...        ...
# 874       1       1         700   Yes  Yes           No      No        Yes
# 875       2       2           1   Yes  Yes           No     Yes        Yes
# 876     3.5       4       3,980    No   No           No      No         No
# 877       2       3       2,552    No  Yes           No      No        Yes
# 878     3.5       4       4,311    No   No           No      No         No
#
#     Floors Roofdeck Storage Fireplace
# 0       No       No      No        No
# 1       No       No      No        No
# 2       No       No      No        No
# 3       No       No      No        No
# 4       No       No      No        No
# ..     ...      ...     ...       ...
# 874     No       No      No        No
# 875     No       No      No       Yes
# 876     No       No      No        No
# 877     No      Yes      No        No
# 878     No       No      No        No
#
# [879 rows x 16 columns]

# %%
dallas.isnull().sum()
# Out:
# URL             0
# Address         0
# Rental Price    0
# Deposit         0
# Bathroom        0
# Bedroom         0
# Rental Area     0
# Pets            0
# AC              0
# Washer_Dryer    0
# Parking         0
# Dishwasher      0
# Floors          0
# Roofdeck        0
# Storage         0
# Fireplace       0
# dtype: int64

# %%
import numpy as np

# %%
dallas = dallas.replace("np.nan", np.nan)

# %%
dallas.isnull().sum()
# Out:
# URL               0
# Address           1
# Rental Price      0
# Deposit         268
# Bathroom         10
# Bedroom           0
# Rental Area     114
# Pets              0
# AC                0
# Washer_Dryer      0
# Parking           0
# Dishwasher        0
# Floors            0
# Roofdeck          0
# Storage           0
# Fireplace         0
# dtype: int64

# %%
# Cleaning dataframe , drop nan from area since its target variable
dallas = dallas[~dallas['Rental Area'].isna()]
dallas
# Out:
#                                                    URL  \
# 0    https://rentberry.com/houses/111638657-five-br...
# 1    https://rentberry.com/houses/109702755-five-br...
# 2    https://rentberry.com/houses/117440948-four-br...
# 3    https://rentberry.com/houses/117440768-three-b...
# 4    https://rentberry.com/houses/116550845-four-br...
# ..                                                 ...
# 874  https://rentberry.com/houses/98277630-three-br...
# 875  https://rentberry.com/houses/96922820-one-br-d...
# 876  https://rentberry.com/apartments/98805585-two-...
# 877  https://rentberry.com/houses/115930970-four-br...
# 878  https://rentberry.com/houses/90098599-three-br...
#
#                                                Address Rental Price Deposit  \
# 0                                         7132 Hunt Ln       $8,750   8,750
# 1                                     4713 Highgate Ln      $10,950  10,950
# 2          1466 Plummer Drive, Rockwall, TX 75087, USA       $4,000   4,000
# 3    2647 Valley Glen Drive, Richardson, TX 75080, USA       $3,400   3,400
# 4              3814 Eaton Drive, Dallas, TX 75220, USA       $8,000   8,000
# ..                                                 ...          ...     ...
# 874                                         Dallas, TX       $6,990     NaN
# 875                                         Dallas, TX       $2,760     NaN
# 876        5673 St. Thomas Drive, Plano, TX 75094, USA       $3,720   3,950
# 877  2055 Dripping Springs Drive, Kaufman County, T...       $3,950   2,407
# 878  4723 Breckinridge Boulevard, Richardson, TX 75...       $2,407   3,800
#
#     Bathroom Bedroom Rental Area Pets   AC Washer_Dryer Parking Dishwasher  \
# 0       2.5       5       2,910   Yes  Yes           No      No        Yes
# 1       2.5       5       2,747   Yes  Yes           No      No        Yes
# 2         3       4       3,030    No   No           No      No         No
# 3         2       3       2,290    No   No           No      No         No
# 4       4.5       4       4,067    No   No           No      No         No
# ..       ...     ...         ...  ...  ...          ...     ...        ...
# 874       1       1         700   Yes  Yes           No      No        Yes
# 875       2       2           1   Yes  Yes           No     Yes        Yes
# 876     3.5       4       3,980    No   No           No      No         No
# 877       2       3       2,552    No  Yes           No      No        Yes
# 878     3.5       4       4,311    No   No           No      No         No
#
#     Floors Roofdeck Storage Fireplace
# 0       No       No      No        No
# 1       No       No      No        No
# 2       No       No      No        No
# 3       No       No      No        No
# 4       No       No      No        No
# ..     ...      ...     ...       ...
# 874     No       No      No        No
# 875     No       No      No       Yes
# 876     No       No      No        No
# 877     No      Yes      No        No
# 878     No       No      No        No
#
# [765 rows x 16 columns]

# %%
dallas.insert(0, 'Sl_No', range(1, 1 + dallas.shape[0]))
dallas.insert(3, 'City', "Dallas")
dallas.insert(4, 'State', "TX")
dallas.insert(5, 'Country', "USA")

dallas
# Out:
#      Sl_No                                                URL  \
# 0        1  https://rentberry.com/houses/111638657-five-br...
# 1        2  https://rentberry.com/houses/109702755-five-br...
# 2        3  https://rentberry.com/houses/117440948-four-br...
# 3        4  https://rentberry.com/houses/117440768-three-b...
# 4        5  https://rentberry.com/houses/116550845-four-br...
# ..     ...                                                ...
# 874    761  https://rentberry.com/houses/98277630-three-br...
# 875    762  https://rentberry.com/houses/96922820-one-br-d...
# 876    763  https://rentberry.com/apartments/98805585-two-...
# 877    764  https://rentberry.com/houses/115930970-four-br...
# 878    765  https://rentberry.com/houses/90098599-three-br...
#
#                                                Address    City State Country  \
# 0                                         7132 Hunt Ln  Dallas    TX     USA
# 1                                     4713 Highgate Ln  Dallas    TX     USA
# 2          1466 Plummer Drive, Rockwall, TX 75087, USA  Dallas    TX     USA
# 3    2647 Valley Glen Drive, Richardson, TX 75080, USA  Dallas    TX     USA
# 4              3814 Eaton Drive, Dallas, TX 75220, USA  Dallas    TX     USA
# ..                                                 ...     ...   ...     ...
# 874                                         Dallas, TX  Dallas    TX     USA
# 875                                         Dallas, TX  Dallas    TX     USA
# 876        5673 St. Thomas Drive, Plano, TX 75094, USA  Dallas    TX     USA
# 877  2055 Dripping Springs Drive, Kaufman County, T...  Dallas    TX     USA
# 878  4723 Breckinridge Boulevard, Richardson, TX 75...  Dallas    TX     USA
#
#     Rental Price Deposit Bathroom Bedroom Rental Area Pets   AC Washer_Dryer  \
# 0         $8,750   8,750     2.5       5       2,910   Yes  Yes           No
# 1        $10,950  10,950     2.5       5       2,747   Yes  Yes           No
# 2         $4,000   4,000       3       4       3,030    No   No           No
# 3         $3,400   3,400       2       3       2,290    No   No           No
# 4         $8,000   8,000     4.5       4       4,067    No   No           No
# ..           ...     ...      ...     ...         ...  ...  ...          ...
# 874       $6,990     NaN       1       1         700   Yes  Yes           No
# 875       $2,760     NaN       2       2           1   Yes  Yes           No
# 876       $3,720   3,950     3.5       4       3,980    No   No           No
# 877       $3,950   2,407       2       3       2,552    No  Yes           No
# 878       $2,407   3,800     3.5       4       4,311    No   No           No
#
#     Parking Dishwasher Floors Roofdeck Storage Fireplace
# 0        No        Yes     No       No      No        No
# 1        No        Yes     No       No      No        No
# 2        No         No     No       No      No        No
# 3        No         No     No       No      No        No
# 4        No         No     No       No      No        No
# ..      ...        ...    ...      ...     ...       ...
# 874      No        Yes     No       No      No        No
# 875     Yes        Yes     No       No      No       Yes
# 876      No         No     No       No      No        No
# 877      No        Yes     No      Yes      No        No
# 878      No         No     No       No      No        No
#
# [765 rows x 20 columns]

# %% [markdown]
# # Creating Table

# %% [markdown]
# ### Table 1

# %%
Sl_no = dallas['Sl_No'].tolist()
Address = dallas['Address'].tolist()
city = dallas['City'].tolist()
state = dallas['State'].tolist()
country = dallas['Country'].tolist()
price = dallas['Rental Price'].tolist()
Deposit = dallas['Deposit'].tolist()

dallas_Table1 =pd.DataFrame({
    'Sl_No':Sl_no,
    'Address': Address,
    'City': city,
    'State': state,
    'Country' : country,
    'Price': price,
    'Deposit': Deposit
})
dallas_Table1


dallas_Table1.to_csv('dallas_Table1.csv', index=False)

# %% [markdown]
# ### Table 2

# %%
Sl_no = dallas['Sl_No'].tolist()
Beds = dallas['Bedroom'].tolist()
Baths = dallas['Bathroom'].tolist()
R_area = dallas['Rental Area'].tolist()
pets = dallas['Pets'].tolist()

dallas_Table2 =pd.DataFrame({
    'Sl_No':Sl_no,
    'Bedrooms': Beds,
    'Bathrooms': Baths,
    'Area' : R_area,
    'Pets Allowed': pets,
})
dallas_Table2


dallas_Table2.to_csv('dallas_Table2.csv', index=False)

# %% [markdown]
# ### Table 3

# %%
Sl_no = dallas['Sl_No'].tolist()
AC = dallas['AC'].tolist()
washer = dallas['Washer_Dryer'].tolist()
Parking = dallas['Parking'].tolist()
Dishwasher = dallas['Dishwasher'].tolist()
floor = dallas['Floors'].tolist()
roof = dallas['Roofdeck'].tolist()
storage = dallas['Storage'].tolist()
fireplace = dallas['Fireplace'].tolist()


dallas_Table3 =pd.DataFrame({
    'Sl_No':Sl_no,
    'Washer/Dryer': washer,
    'AC': AC,
    'Parking' : Parking,
    'Fireplace': fireplace,
    'Dishwasher': Dishwasher,
    'Hardwood floors': floor,
    'Roofdeck': roof,
    'storage': storage
})

dallas_Table3


dallas_Table3.to_csv('dallas_Table3.csv', index=False)

# %%
dallas.to_csv('dallas.csv', index = False)

# %% [markdown]
# ### Vancouver, BC, Canada

# %%
driver = webdriver.Chrome()
driver.get('https://rentberry.com/ca/apartments/s/vancouver-bc-canada')
time.sleep(2)

# %%
va_URL = []
va_Price = []

# %%
start=0
end=5


for page in range(start,end):
    url_tags= driver.find_elements(By.XPATH,'//a[@class="property-card-bottom-address__text link-ghost font-xs one-line-string"]')
    price = driver.find_elements(By.XPATH,'//rb-property-card-bottom[@class="property-card__bottom"]/div/div/rb-property-card-price/div/p')
    
    for _ in range(200):
        driver.execute_script("window.scrollBy(0,200)")
        
    for t in url_tags:
        va_URL.append(t.get_attribute('href'))
    for a in price:
        va_Price.append(a.text)
        
    next_page = driver.find_element(By.XPATH,'//span[@class="pagination-arrow-next"]')
    next_page.click()
    

    time.sleep(5)

# %%
va_Pets = []
va_Area = []
va_Address = []
va_Deposit = []
va_Beds = []
va_Bathroom = []
va_Washer_Dryer =[]
va_AC = []
va_Parking=[]
va_Fireplace=[]
va_Dishwasher=[]
va_Floors=[]
va_Roofdeck=[]
va_Storage=[]

# %%
for t in va_URL:
    driver.get(t)
    time.sleep(5)
    
    try:
        add = driver.find_element(By.XPATH,'/html/body/rb-core/div/rb-property/div/div[1]/rb-property-main-info/section/div/div/rb-property-data/div/h4/span/span')
        va_Address.append(add.text)
    except NoSuchElementException:
        va_Address.append('-')
        
    try:
        bed = driver.find_element(By.XPATH,'/html/body/rb-core/div/rb-property/div/div[1]/rb-property-main-info/rb-apartment-card-swiper/div/div[3]/rb-apartment-internals/section/div[1]/div[2]/span[1]')
        va_Beds.append(bed.text)
    except NoSuchElementException:
        va_Beds.append('-') 
        
    try:
        bath = driver.find_element(By.XPATH,'/html/body/rb-core/div/rb-property/div/div[1]/rb-property-main-info/rb-apartment-card-swiper/div/div[3]/rb-apartment-internals/section/div[2]/div[2]/span[1]')
        va_Bathroom.append(bath.text)
    except NoSuchElementException:
        va_Bathroom.append('-') 
        
    try:
        sqft = driver.find_element(By.XPATH,'/html/body/rb-core/div/rb-property/div/div[1]/rb-property-main-info/rb-apartment-card-swiper/div/div[3]/rb-apartment-internals/section/div[3]/div[2]/span[1]')
        va_Area.append(sqft.text.replace(' \nSq Ft',''))
    except NoSuchElementException:
        va_Area.append('-')
        
    try:
        pet = driver.find_element(By.XPATH,'/html/body/rb-core/div/rb-property/div/div[1]/rb-property-main-info/section/div/div/rb-property-facilities/section/div[4]')
        va_Pets.append(pet.text.replace("\n", " "))
    except NoSuchElementException:
        va_Pets.append('-')
        
    try:
        adv = driver.find_element(By.XPATH,'/html/body/rb-core/div/rb-property/div/div[2]/div/rb-apply-block/div/div/rb-button-square/button/span/span[2]/span[1]')
        va_Deposit.append(adv.text.replace("Apply for $",''))
    except NoSuchElementException:
        va_Deposit.append('-')
        
    try:
        was = driver.find_element(By.XPATH, "//*[contains(@class,'icon washerUnit')]")
        va_Washer_Dryer.append('Yes')
    except NoSuchElementException:
        va_Washer_Dryer.append('No')   
        
    try:
        ac = driver.find_element(By.XPATH,"//*[contains(@class,'airConditioning icon')]")
        va_AC.append('Yes')
    except NoSuchElementException:
        va_AC.append('No')
       
    try:
        park = driver.find_element(By.XPATH,"//*[contains(@class,'icon parking')]")
        va_Parking.append('Yes')
    except NoSuchElementException:
        va_Parking.append('No') 

    try:
        dish = driver.find_element(By.XPATH,"//*[contains(@class,'dishwasher icon')]")
        va_Dishwasher.append('Yes')
    except NoSuchElementException: 
        va_Dishwasher.append('No')
    try:
        hard = driver.find_element(By.XPATH,"//*[contains(@class,'hardwoodFloors icon')]")
        va_Floors.append('Yes')
    except NoSuchElementException:
        va_Floors.append('No')
        
    try:
        roof = driver.find_element(By.XPATH,"//*[contains(@class,'icon roofDeck')]")
        va_Roofdeck.append('Yes')  
    except NoSuchElementException:
        va_Roofdeck.append('No')
        
    try:
        store = driver.find_element(By.XPATH, "//*[contains(@class,'icon storage')]")
        va_Storage.append('Yes')
    except NoSuchElementException: 
        va_Storage.append('No')
                    
    try:
        fire = driver.find_element(By.XPATH, "//*[contains(@class,'fireplace icon')]")
        va_Fireplace.append('Yes')
    except NoSuchElementException:  
        va_Fireplace.append('No')

# %%
print(len(va_URL), len(va_Price))
# Out:
# 374 374

# %%
print(len(va_URL), len(va_Price),len(va_Address),len(va_Bathroom),len(va_Beds),len(va_Area),len(va_Pets),len(va_Deposit),len(va_AC),len(va_Washer_Dryer),len(va_Parking),len(va_Dishwasher),len(va_Floors),len(va_Roofdeck),len(va_Storage), len(va_Fireplace))
# Out:
# 374 374 374 374 374 374 374 374 374 374 374 374 374 374 374 374

# %%
vancouver = pd.DataFrame({'URL': va_URL, 'Price':va_Price, 'Area': va_Area,'Bedroom':va_Beds,'Bathrooms': va_Bathroom,'Pets':va_Pets,'deposit':va_Deposit,'address':va_Address,'Washer':va_Washer_Dryer,'AC':va_AC,'Parking':va_Parking,'Dishwasher':va_Dishwasher, 'Storage':va_Storage,'Fireplace':va_Fireplace,'Roofdeck': va_Roofdeck, 'HardwoodFloors':va_Floors})
vancouver
# Out:
#                                                    URL    Price    Area  \
# 0    https://rentberry.com/ca/houses/96265544-one-b...   $4,097    450
# 1    https://rentberry.com/ca/apartments/96527586-o...   $5,284    360
# 2    https://rentberry.com/ca/apartments/95680490-t...   $7,505    900
# 3    https://rentberry.com/ca/apartments/109143205-...   $6,242       -
# 4    https://rentberry.com/ca/houses/110118969-five...   $1,075       -
# ..                                                 ...      ...     ...
# 369  https://rentberry.com/ca/houses/95818258-three...   $9,305  1,000
# 370  https://rentberry.com/ca/houses/96748040-one-b...   $2,680       -
# 371  https://rentberry.com/ca/houses/96819063-four-...  $23,091  5,000
# 372  https://rentberry.com/ca/houses/96083171-two-b...   $3,753       -
# 373  https://rentberry.com/ca/houses/109138623-thre...  $17,883       -
#
#     Bedroom Bathrooms             Pets deposit  \
# 0        1         1   No pets Allowed       -
# 1        1         1   No pets Allowed       -
# 2        2         2      Dogs Allowed       -
# 3        1         1      Cats Allowed       -
# 4        5         2                 -       -
# ..      ...       ...              ...     ...
# 369      3         3   No pets Allowed       -
# 370      1         1                 -       -
# 371      4         5      Dogs Allowed       -
# 372      2         2                 -       -
# 373      3         3      Cats Allowed       -
#
#                                                address Washer   AC Parking  \
# 0    Reality Church Vancouver, 808 East 19th Avenue...     No   No     Yes
# 1    Grandview-Woodland, Vancouver, BC V5L 2H6, Canada     No  Yes     Yes
# 2                        Vancouver, BC V6B 0G1, Canada     No  Yes     Yes
# 3              Yaletown, Vancouver, BC V6B 6L6, Canada     No   No      No
# 4          Vancouver, Kensington-Cedar Cottage, BC, CA     No   No      No
# ..                                                 ...    ...  ...     ...
# 369                      Vancouver, BC V5P 1S3, Canada     No  Yes     Yes
# 370  Kensington-Cedar Cottage, Vancouver, BC V5V 1C...     No   No     Yes
# 371       Arbutus Ridge, Vancouver, BC V6N 3Y7, Canada     No  Yes     Yes
# 372        South Cambie, Vancouver, BC V5Y 2E7, Canada     No   No     Yes
# 373       Hastings East, Vancouver, BC V5K 2C6, Canada     No  Yes     Yes
#
#     Dishwasher Storage Fireplace Roofdeck HardwoodFloors
# 0          Yes      No        No       No             No
# 1           No      No        No       No             No
# 2          Yes      No        No       No             No
# 3          Yes      No        No       No             No
# 4           No      No        No       No             No
# ..         ...     ...       ...      ...            ...
# 369        Yes      No       Yes       No             No
# 370         No      No        No       No             No
# 371        Yes      No       Yes       No             No
# 372        Yes      No        No       No             No
# 373         No      No       Yes       No             No
#
# [374 rows x 16 columns]

# %%
rent1 = pd.concat([miami, jersey, lasvegas, irvine, nashville, pittsburg, sanfrancisco, sanjose, toronto, vancouver],axis=0)
rent1
# Out:
#                                                    URL    Price    Area  \
# 0    https://rentberry.com/apartments/115918379-thr...   $7,900  1,526
# 1    https://rentberry.com/apartments/96699282-one-...   $4,560    431
# 2    https://rentberry.com/houses/97303817-five-br-...  $37,770       -
# 3    https://rentberry.com/apartments/109130572-two...   $6,840  1,097
# 4    https://rentberry.com/apartments/114055668-one...   $1,875    349
# ..                                                 ...      ...     ...
# 369  https://rentberry.com/ca/houses/95818258-three...   $9,305  1,000
# 370  https://rentberry.com/ca/houses/96748040-one-b...   $2,680       -
# 371  https://rentberry.com/ca/houses/96819063-four-...  $23,091  5,000
# 372  https://rentberry.com/ca/houses/96083171-two-b...   $3,753       -
# 373  https://rentberry.com/ca/houses/109138623-thre...  $17,883       -
#
#     Bedroom Bathrooms             Pets deposit  \
# 0        3         3      Dogs Allowed   7,900
# 1        1         1   No pets Allowed       -
# 2        5         4      Cats Allowed       -
# 3        2         2   No pets Allowed       -
# 4        1         1                 -   1,875
# ..      ...       ...              ...     ...
# 369      3         3   No pets Allowed       -
# 370      1         1                 -       -
# 371      4         5      Dogs Allowed       -
# 372      2         2                 -       -
# 373      3         3      Cats Allowed       -
#
#                                                address Washer   AC Parking  \
# 0                            3131 Northeast 7th Avenue     No   No      No
# 1                                     Coral Gables, FL     No  Yes     Yes
# 2                                            Miami, FL     No  Yes     Yes
# 3                                            Miami, FL     No  Yes      No
# 4    1971 Bay Drive, Isle of Normandy, Miami Beach,...     No   No      No
# ..                                                 ...    ...  ...     ...
# 369                      Vancouver, BC V5P 1S3, Canada     No  Yes     Yes
# 370  Kensington-Cedar Cottage, Vancouver, BC V5V 1C...     No   No     Yes
# 371       Arbutus Ridge, Vancouver, BC V6N 3Y7, Canada     No  Yes     Yes
# 372        South Cambie, Vancouver, BC V5Y 2E7, Canada     No   No     Yes
# 373       Hastings East, Vancouver, BC V5K 2C6, Canada     No  Yes     Yes
#
#     Dishwasher Storage Fireplace Roofdeck HardwoodFloors
# 0           No      No        No       No             No
# 1           No      No       Yes       No             No
# 2          Yes      No       Yes       No             No
# 3          Yes      No        No       No             No
# 4           No      No        No       No             No
# ..         ...     ...       ...      ...            ...
# 369        Yes      No       Yes       No             No
# 370         No      No        No       No             No
# 371        Yes      No       Yes       No             No
# 372        Yes      No        No       No             No
# 373         No      No       Yes       No             No
#
# [4878 rows x 16 columns]

# %%
rent1 = pd.concat([Austin, Bf_ny, dallas, miami, jersey, lasvegas, irvine, nashville, pittsburg, sanfrancisco, sanjose, toronto, vancouver],axis=0)
rent1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17584\4230902197.py in <module>
# ----> 1 rent1 = pd.concat([Austin, Bf_ny, dallas, miami, jersey, lasvegas, irvine, nashville, pittsburg, sanfrancisco, sanjose, toronto, vancouver],axis=0)
#       2 rent1
#
# NameError: name 'Austin' is not defined

# %%
rent1.to_csv("rent.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9900\2031170066.py in <module>
# ----> 1 rent1.to_csv("rent.csv")
#
# NameError: name 'rent1' is not defined
