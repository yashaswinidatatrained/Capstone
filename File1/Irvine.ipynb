# %%
import selenium
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import NoSuchElementException

from bs4 import BeautifulSoup
import requests

import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %% [markdown]
# ### Scraping For Irvine, CA

# %%
#opening the rentberry Austin,Tx page on automated chrome browser
driver = webdriver.Chrome()
driver.get('https://rentberry.com/apartments/s/irvine-ca')
time.sleep(2)

# %%
rent_URL = []
rent_Price = []

# %%
# to scrap URL of 66 pages
start = 0
end = 30

for page in range(start,end):
    url_tags= driver.find_elements(By.XPATH,'//a[@class="property-card-bottom-address__text link-ghost font-xs one-line-string"]')
    price = driver.find_elements(By.XPATH,'//rb-property-card-bottom[@class="property-card__bottom"]/div/div/rb-property-card-price/div/p')
   
    for _ in range(100):
        driver.execute_script("window.scrollBy(0,1000)")
        
    for t in url_tags:
        rent_URL.append(t.get_attribute('href'))
    for a in price:
        rent_Price.append(a.text)
        
    next_page = driver.find_element(By.XPATH,'//span[@class="pagination-arrow-next"]')
    next_page.click()
 
    time.sleep(5)

# %%
print(len(rent_URL),len(rent_Price))
# Out:
# 660 660

# %%
rent_Pets = []
rent_Area = []
rent_Address = []
rent_Deposit = []
rent_Beds = []
rent_Bathroom = []
rent_Washer_Dryer =[]
rent_AC = []
rent_Parking=[]
rent_Fireplace=[]
rent_Dishwasher=[]
rent_Floors=[]
rent_Roofdeck=[]
rent_Storage=[]

# %%
for t in rent_URL[549:]:
    driver.get(t)
    time.sleep(5)
    
    
    try:
        add = driver.find_element(By.XPATH,'/html/body/rb-core/div/rb-property/div/rb-property-main-info/section/div/div/rb-property-data/div/h4/span/span')
        rent_Address.append(add.text)
    except NoSuchElementException:
        rent_Address.append(np.nan)
        
    try:
        bed = driver.find_element(By.XPATH,"//*[contains(@class,'bedrooms')]")
        rent_Beds.append(bed.text)
    except NoSuchElementException:
        rent_Beds.append(np.nan) 
        
    try:
        bath = driver.find_element(By.XPATH,"//*[contains(@class,'bathrooms')]")
        rent_Bathroom.append(bath.text)
    except NoSuchElementException:
        rent_Bathroom.append(np.nan) 
        
    try:
        sqft = driver.find_element(By.XPATH,"//*[contains(@class,'space')]")
        rent_Area.append(sqft.text)
    except NoSuchElementException:
        rent_Area.append(np.nan)
        
    try:
        pets = driver.find_element(By.XPATH,"//*[contains(@class,'dog-icon facilities-param-icon')]" or "//*[contains(@class,'cat-icon facilities-param-icon')]")
        rent_Pets.append('Yes')
    except NoSuchElementException:
        rent_Pets.append('No')
        
    try:
        adv = driver.find_element(By.XPATH,'/html/body/rb-core/div/rb-property/div/div[2]/div/rb-apply-block/div/div/rb-button-square/button/span/span[2]/span[1]')
        rent_Deposit.append(adv.text.replace("Apply for $",''))
    except NoSuchElementException:
        rent_Deposit.append(np.nan)
        
    try:
        was = driver.find_element(By.XPATH, "//*[contains(@class,'icon washerUnit')]")
        rent_Washer_Dryer.append('Yes')
    except NoSuchElementException:
        rent_Washer_Dryer.append('No')   
        
    try:
        ac = driver.find_element(By.XPATH,"//*[contains(@class,'airConditioning icon')]")
        rent_AC.append('Yes')
    except NoSuchElementException:
        rent_AC.append('No')
       
    try:
        park = driver.find_element(By.XPATH,"//*[contains(@class,'icon parking')]")
        rent_Parking.append('Yes')
    except NoSuchElementException:
        rent_Parking.append('No') 

    try:
        dish = driver.find_element(By.XPATH,"//*[contains(@class,'dishwasher icon')]")
        rent_Dishwasher.append('Yes')
    except NoSuchElementException: 
        rent_Dishwasher.append('No')
    try:
        hard = driver.find_element(By.XPATH,"//*[contains(@class,'hardwoodFloors icon')]")
        rent_Floors.append('Yes')
    except NoSuchElementException:
        rent_Floors.append('No')
        
    try:
        roof = driver.find_element(By.XPATH,"//*[contains(@class,'icon roofDeck')]")
        rent_Roofdeck.append('Yes')  
    except NoSuchElementException:
        rent_Roofdeck.append('No')
        
    try:
        store = driver.find_element(By.XPATH, "//*[contains(@class,'icon storage')]")
        rent_Storage.append('Yes')
    except NoSuchElementException: 
        rent_Storage.append('No')
                    
    try:
        fire = driver.find_element(By.XPATH, "//*[contains(@class,'fireplace icon')]")
        rent_Fireplace.append('Yes')
    except NoSuchElementException:  
        rent_Fireplace.append('No')

# %%
print(len(rent_URL), len(rent_Price),len(rent_Address),len(rent_Bathroom),len(rent_Beds),len(rent_Area),len(rent_Pets),len(rent_Deposit),len(rent_AC),len(rent_Washer_Dryer),len(rent_Parking),len(rent_Dishwasher),len(rent_Floors),len(rent_Roofdeck),len(rent_Storage), len(rent_Fireplace))
# Out:
# 660 660 660 660 660 660 660 660 660 660 660 660 660 660 660 660

# %%
irvine = pd.DataFrame({'URL':rent_URL,'Address':rent_Address,'Rental Price':rent_Price,'Deposit':rent_Deposit,
                      'Bathroom':rent_Bathroom,'Bedroom':rent_Beds,'Rental Area':rent_Area,'Pets':rent_Pets,
                      'AC':rent_AC,'Washer_Dryer':rent_Washer_Dryer,'Parking':rent_Parking,'Dishwasher':rent_Dishwasher,
                      'Floors':rent_Floors,'Roofdeck':rent_Roofdeck,'Storage':rent_Storage,'Fireplace':rent_Fireplace})
irvine
# Out:
#                                                    URL  \
# 0    https://rentberry.com/apartments/90788599-two-...
# 1    https://rentberry.com/houses/115653628-five-br...
# 2    https://rentberry.com/houses/115032340-four-br...
# 3    https://rentberry.com/houses/117712111-five-br...
# 4    https://rentberry.com/houses/115668713-four-br...
# ..                                                 ...
# 655  https://rentberry.com/apartments/117375865-fou...
# 656  https://rentberry.com/apartments/115745542-one...
# 657  https://rentberry.com/apartments/117227909-two...
# 658  https://rentberry.com/apartments/117370195-fou...
# 659  https://rentberry.com/apartments/117227658-fou...
#
#                                                Address Rental Price Deposit  \
# 0            16531 Alliance Ave, Tustin, CA 92780, USA       $2,795   2,795
# 1              63 Vernal Spring, Irvine, CA 92603, USA      $29,500  29,500
# 2                     139 Arden, Irvine, CA 92620, USA       $5,500   5,500
# 3                   53 Owl Lane, Irvine, CA 92618, USA      $11,800  11,800
# 4                         Fiore, Irvine, CA 92602, USA       $6,500   6,500
# ..                                                 ...          ...     ...
# 655  17 Fecamp, San Joaquin Hills, Newport Beach, C...       $6,394     NaN
# 656  Subway, North Tustin Avenue, Santa Ana, CA 927...       $1,997     NaN
# 657       123 Via Estrada, Laguna Woods, CA 92637, USA       $2,997     NaN
# 658     32 Santa Catalina Aisle, Irvine, CA 92606, USA       $4,597     NaN
# 659                 113 Measure, Irvine, CA 92618, USA       $7,494     NaN
#
#     Bathroom Bedroom Rental Area Pets   AC Washer_Dryer Parking Dishwasher  \
# 0         2       2       1,000    No  Yes           No     Yes         No
# 1       5.5       5       6,492    No   No           No      No         No
# 2       2.5       4       2,105    No   No           No      No         No
# 3       5.5       5       4,684    No   No           No      No         No
# 4         4       4       2,753    No   No           No      No         No
# ..       ...     ...         ...  ...  ...          ...     ...        ...
# 655       1       4          NaN   No   No           No      No         No
# 656       1       1          NaN   No   No           No      No         No
# 657       1       2          NaN   No   No           No      No         No
# 658       1       4          NaN   No   No           No      No         No
# 659       1       4          NaN   No   No           No      No         No
#
#     Floors Roofdeck Storage Fireplace
# 0      Yes       No      No        No
# 1       No       No      No        No
# 2       No       No      No        No
# 3       No       No      No        No
# 4       No       No      No        No
# ..     ...      ...     ...       ...
# 655     No       No      No        No
# 656     No       No      No        No
# 657     No       No      No        No
# 658     No       No      No        No
# 659     No       No      No        No
#
# [660 rows x 16 columns]

# %%
irvine.isnull().sum()
# Out:
# URL               0
# Address          19
# Rental Price      0
# Deposit         325
# Bathroom         18
# Bedroom          16
# Rental Area     201
# Pets              0
# AC                0
# Washer_Dryer      0
# Parking           0
# Dishwasher        0
# Floors            0
# Roofdeck          0
# Storage           0
# Fireplace         0
# dtype: int64

# %%
# Cleaning dataframe , drop nan from area since its target variable
irvine = irvine[~irvine['Rental Area'].isna()]
irvine
# Out:
#                                                    URL  \
# 0    https://rentberry.com/apartments/90788599-two-...
# 1    https://rentberry.com/houses/115653628-five-br...
# 2    https://rentberry.com/houses/115032340-four-br...
# 3    https://rentberry.com/houses/117712111-five-br...
# 4    https://rentberry.com/houses/115668713-four-br...
# ..                                                 ...
# 619  https://rentberry.com/apartments/116974565-two...
# 631  https://rentberry.com/apartments/116978710-fou...
# 635  https://rentberry.com/apartments/117210459-thr...
# 642  https://rentberry.com/houses/117683847-two-br-...
# 643  https://rentberry.com/houses/65101809-three-br...
#
#                                           Address Rental Price Deposit  \
# 0       16531 Alliance Ave, Tustin, CA 92780, USA       $2,795   2,795
# 1         63 Vernal Spring, Irvine, CA 92603, USA      $29,500  29,500
# 2                139 Arden, Irvine, CA 92620, USA       $5,500   5,500
# 3              53 Owl Lane, Irvine, CA 92618, USA      $11,800  11,800
# 4                    Fiore, Irvine, CA 92602, USA       $6,500   6,500
# ..                                            ...          ...     ...
# 619      4555 Sandburg Way, Irvine, CA 92612, USA       $4,993     NaN
# 631        13702 Utt Drive, Tustin, CA 92780, USA       $4,796     NaN
# 635  7 Rue Fontaine, Newport Beach, CA 92660, USA      $13,235     NaN
# 642                                 313 N Calhoun       $1,150     NaN
# 643        27 Del Perlatto, Irvine, CA 92614, USA       $4,000   4,000
#
#     Bathroom Bedroom Rental Area Pets   AC Washer_Dryer Parking Dishwasher  \
# 0         2       2       1,000    No  Yes           No     Yes         No
# 1       5.5       5       6,492    No   No           No      No         No
# 2       2.5       4       2,105    No   No           No      No         No
# 3       5.5       5       4,684    No   No           No      No         No
# 4         4       4       2,753    No   No           No      No         No
# ..       ...     ...         ...  ...  ...          ...     ...        ...
# 619       1       2         167    No   No           No      No         No
# 631       1       4         227    No   No           No      No         No
# 635       1       3         252    No   No           No      No         No
# 642       1       2         760   Yes   No           No     Yes        Yes
# 643       3       3       1,762    No   No           No      No         No
#
#     Floors Roofdeck Storage Fireplace
# 0      Yes       No      No        No
# 1       No       No      No        No
# 2       No       No      No        No
# 3       No       No      No        No
# 4       No       No      No        No
# ..     ...      ...     ...       ...
# 619     No       No      No        No
# 631     No       No      No        No
# 635     No       No      No        No
# 642     No       No      No        No
# 643     No       No      No        No
#
# [459 rows x 16 columns]

# %%
irvine.insert(0, 'Sl_No', range(1, 1 + irvine.shape[0]))
irvine.insert(3, 'City', "Irvine")
irvine.insert(4, 'State', "CA")
irvine.insert(5, 'Country', "USA")

irvine
# Out:
#      Sl_No                                                URL  \
# 0        1  https://rentberry.com/apartments/90788599-two-...
# 1        2  https://rentberry.com/houses/115653628-five-br...
# 2        3  https://rentberry.com/houses/115032340-four-br...
# 3        4  https://rentberry.com/houses/117712111-five-br...
# 4        5  https://rentberry.com/houses/115668713-four-br...
# ..     ...                                                ...
# 619    455  https://rentberry.com/apartments/116974565-two...
# 631    456  https://rentberry.com/apartments/116978710-fou...
# 635    457  https://rentberry.com/apartments/117210459-thr...
# 642    458  https://rentberry.com/houses/117683847-two-br-...
# 643    459  https://rentberry.com/houses/65101809-three-br...
#
#                                           Address    City State Country  \
# 0       16531 Alliance Ave, Tustin, CA 92780, USA  Irvine    CA     USA
# 1         63 Vernal Spring, Irvine, CA 92603, USA  Irvine    CA     USA
# 2                139 Arden, Irvine, CA 92620, USA  Irvine    CA     USA
# 3              53 Owl Lane, Irvine, CA 92618, USA  Irvine    CA     USA
# 4                    Fiore, Irvine, CA 92602, USA  Irvine    CA     USA
# ..                                            ...     ...   ...     ...
# 619      4555 Sandburg Way, Irvine, CA 92612, USA  Irvine    CA     USA
# 631        13702 Utt Drive, Tustin, CA 92780, USA  Irvine    CA     USA
# 635  7 Rue Fontaine, Newport Beach, CA 92660, USA  Irvine    CA     USA
# 642                                 313 N Calhoun  Irvine    CA     USA
# 643        27 Del Perlatto, Irvine, CA 92614, USA  Irvine    CA     USA
#
#     Rental Price Deposit Bathroom Bedroom Rental Area Pets   AC Washer_Dryer  \
# 0         $2,795   2,795       2       2       1,000    No  Yes           No
# 1        $29,500  29,500     5.5       5       6,492    No   No           No
# 2         $5,500   5,500     2.5       4       2,105    No   No           No
# 3        $11,800  11,800     5.5       5       4,684    No   No           No
# 4         $6,500   6,500       4       4       2,753    No   No           No
# ..           ...     ...      ...     ...         ...  ...  ...          ...
# 619       $4,993     NaN       1       2         167    No   No           No
# 631       $4,796     NaN       1       4         227    No   No           No
# 635      $13,235     NaN       1       3         252    No   No           No
# 642       $1,150     NaN       1       2         760   Yes   No           No
# 643       $4,000   4,000       3       3       1,762    No   No           No
#
#     Parking Dishwasher Floors Roofdeck Storage Fireplace
# 0       Yes         No    Yes       No      No        No
# 1        No         No     No       No      No        No
# 2        No         No     No       No      No        No
# 3        No         No     No       No      No        No
# 4        No         No     No       No      No        No
# ..      ...        ...    ...      ...     ...       ...
# 619      No         No     No       No      No        No
# 631      No         No     No       No      No        No
# 635      No         No     No       No      No        No
# 642     Yes        Yes     No       No      No        No
# 643      No         No     No       No      No        No
#
# [459 rows x 20 columns]

# %% [markdown]
# ### Creating Tables

# %% [markdown]
# ### Table1

# %%
Sl_no = irvine['Sl_No'].tolist()
Address = irvine['Address'].tolist()
city = irvine['City'].tolist()
state = irvine['State'].tolist()
country = irvine['Country'].tolist()
price = irvine['Rental Price'].tolist()
Deposit = irvine['Deposit'].tolist()

irvine_Table1 =pd.DataFrame({
    'Sl_No':Sl_no,
    'Address': Address,
    'City': city,
    'State': state,
    'Country' : country,
    'Price': price,
    'Deposit': Deposit
})
irvine_Table1


irvine_Table1.to_csv('irvine_Table1.csv', index=False)

# %% [markdown]
# ### Table 2

# %%
Sl_no = irvine['Sl_No'].tolist()
Beds = irvine['Bedroom'].tolist()
Baths = irvine['Bathroom'].tolist()
R_area = irvine['Rental Area'].tolist()
pets = irvine['Pets'].tolist()

irvine_Table2 =pd.DataFrame({
    'Sl_No':Sl_no,
    'Bedrooms': Beds,
    'Bathrooms': Baths,
    'Area' : R_area,
    'Pets Allowed': pets,
})
irvine_Table2


irvine_Table2.to_csv('irvine_Table2.csv', index=False)

# %% [markdown]
# ### Table 3

# %%
Sl_no = irvine['Sl_No'].tolist()
AC = irvine['AC'].tolist()
washer = irvine['Washer_Dryer'].tolist()
Parking = irvine['Parking'].tolist()
Dishwasher = irvine['Dishwasher'].tolist()
floor = irvine['Floors'].tolist()
roof = irvine['Roofdeck'].tolist()
storage = irvine['Storage'].tolist()
fireplace = irvine['Fireplace'].tolist()


irvine_Table3 =pd.DataFrame({
    'Sl_No':Sl_no,
    'Washer/Dryer': washer,
    'AC': AC,
    'Parking' : Parking,
    'Fireplace': fireplace,
    'Dishwasher': Dishwasher,
    'Hardwood floors': floor,
    'Roofdeck': roof,
    'storage': storage
})

irvine_Table3


irvine_Table3.to_csv('irvine_Table3.csv', index=False)

# %%
irvine.to_csv('irvine.csv', index = False)
