# %%
import selenium
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import NoSuchElementException

from bs4 import BeautifulSoup
import requests

import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %% [markdown]
# ### Scraping For Pittsburgh,PA

# %%
#opening the rentberry Austin,Tx page on automated chrome browser
driver = webdriver.Chrome()
driver.get('https://rentberry.com/apartments/s/pittsburgh-pa')
time.sleep(2)

# %%
rent_URL = []
rent_Price = []

# %%
# to scrap URL of 66 pages
start = 0
end = 45

for page in range(start,end):
    url_tags= driver.find_elements(By.XPATH,'//a[@class="property-card-bottom-address__text link-ghost font-xs one-line-string"]')
    price = driver.find_elements(By.XPATH,'//rb-property-card-bottom[@class="property-card__bottom"]/div/div/rb-property-card-price/div/p')
   
    for _ in range(100):
        driver.execute_script("window.scrollBy(0,1000)")
        
    for t in url_tags:
        rent_URL.append(t.get_attribute('href'))
    for a in price:
        rent_Price.append(a.text)
        
    next_page = driver.find_element(By.XPATH,'//span[@class="pagination-arrow-next"]')
    next_page.click()
 
    time.sleep(5)

# %%
print(len(rent_URL),len(rent_Price))
# Out:
# 990 990

# %%
rent_Pets = []
rent_Area = []
rent_Address = []
rent_Deposit = []
rent_Beds = []
rent_Bathroom = []
rent_Washer_Dryer =[]
rent_AC = []
rent_Parking=[]
rent_Fireplace=[]
rent_Dishwasher=[]
rent_Floors=[]
rent_Roofdeck=[]
rent_Storage=[]

# %%
for t in rent_URL[974:]:
    driver.get(t)
    time.sleep(5)
    
    
    try:
        add = driver.find_element(By.XPATH,'/html/body/rb-core/div/rb-property/div/rb-property-main-info/section/div/div/rb-property-data/div/h4/span/span')
        rent_Address.append(add.text)
    except NoSuchElementException:
        rent_Address.append(np.nan)
        
    try:
        bed = driver.find_element(By.XPATH,"//*[contains(@class,'bedrooms')]")
        rent_Beds.append(bed.text)
    except NoSuchElementException:
        rent_Beds.append(np.nan) 
        
    try:
        bath = driver.find_element(By.XPATH,"//*[contains(@class,'bathrooms')]")
        rent_Bathroom.append(bath.text)
    except NoSuchElementException:
        rent_Bathroom.append(np.nan) 
        
    try:
        sqft = driver.find_element(By.XPATH,"//*[contains(@class,'space')]")
        rent_Area.append(sqft.text)
    except NoSuchElementException:
        rent_Area.append(np.nan)
        
    try:
        pets = driver.find_element(By.XPATH,"//*[contains(@class,'dog-icon facilities-param-icon')]" or "//*[contains(@class,'cat-icon facilities-param-icon')]")
        rent_Pets.append('Yes')
    except NoSuchElementException:
        rent_Pets.append('No')
        
    try:
        adv = driver.find_element(By.XPATH,'/html/body/rb-core/div/rb-property/div/div[2]/div/rb-apply-block/div/div/rb-button-square/button/span/span[2]/span[1]')
        rent_Deposit.append(adv.text.replace("Apply for $",''))
    except NoSuchElementException:
        rent_Deposit.append(np.nan)
        
    try:
        was = driver.find_element(By.XPATH, "//*[contains(@class,'icon washerUnit')]")
        rent_Washer_Dryer.append('Yes')
    except NoSuchElementException:
        rent_Washer_Dryer.append('No')   
        
    try:
        ac = driver.find_element(By.XPATH,"//*[contains(@class,'airConditioning icon')]")
        rent_AC.append('Yes')
    except NoSuchElementException:
        rent_AC.append('No')
       
    try:
        park = driver.find_element(By.XPATH,"//*[contains(@class,'icon parking')]")
        rent_Parking.append('Yes')
    except NoSuchElementException:
        rent_Parking.append('No') 

    try:
        dish = driver.find_element(By.XPATH,"//*[contains(@class,'dishwasher icon')]")
        rent_Dishwasher.append('Yes')
    except NoSuchElementException: 
        rent_Dishwasher.append('No')
    try:
        hard = driver.find_element(By.XPATH,"//*[contains(@class,'hardwoodFloors icon')]")
        rent_Floors.append('Yes')
    except NoSuchElementException:
        rent_Floors.append('No')
        
    try:
        roof = driver.find_element(By.XPATH,"//*[contains(@class,'icon roofDeck')]")
        rent_Roofdeck.append('Yes')  
    except NoSuchElementException:
        rent_Roofdeck.append('No')
        
    try:
        store = driver.find_element(By.XPATH, "//*[contains(@class,'icon storage')]")
        rent_Storage.append('Yes')
    except NoSuchElementException: 
        rent_Storage.append('No')
                    
    try:
        fire = driver.find_element(By.XPATH, "//*[contains(@class,'fireplace icon')]")
        rent_Fireplace.append('Yes')
    except NoSuchElementException:  
        rent_Fireplace.append('No')

# %%
print(len(rent_URL), len(rent_Price),len(rent_Address),len(rent_Bathroom),len(rent_Beds),len(rent_Area),len(rent_Pets),len(rent_Deposit),len(rent_AC),len(rent_Washer_Dryer),len(rent_Parking),len(rent_Dishwasher),len(rent_Floors),len(rent_Roofdeck),len(rent_Storage), len(rent_Fireplace))
# Out:
# 990 990 990 990 990 990 990 990 990 990 990 990 990 990 990 990

# %%
pittsburg = pd.DataFrame({'URL':rent_URL,'Address':rent_Address,'Rental Price':rent_Price,'Deposit':rent_Deposit,
                      'Bathroom':rent_Bathroom,'Bedroom':rent_Beds,'Rental Area':rent_Area,'Pets':rent_Pets,
                      'AC':rent_AC,'Washer_Dryer':rent_Washer_Dryer,'Parking':rent_Parking,'Dishwasher':rent_Dishwasher,
                      'Floors':rent_Floors,'Roofdeck':rent_Roofdeck,'Storage':rent_Storage,'Fireplace':rent_Fireplace})
pittsburg
# Out:
#                                                    URL  \
# 0    https://rentberry.com/houses/116801876-three-b...
# 1    https://rentberry.com/houses/117569640-three-b...
# 2    https://rentberry.com/houses/116438309-three-b...
# 3    https://rentberry.com/apartments/116569483-one...
# 4    https://rentberry.com/apartments/115581643-one...
# ..                                                 ...
# 985  https://rentberry.com/houses/96672434-three-br...
# 986  https://rentberry.com/apartments/115338578-one...
# 987  https://rentberry.com/houses/116884588-two-br-...
# 988  https://rentberry.com/apartments/115059549-thr...
# 989  https://rentberry.com/apartments/117394990-one...
#
#                                                Address Rental Price Deposit  \
# 0                                                  NaN       $1,515     NaN
# 1                                       3107 Elroy Ave       $1,595   1,595
# 2                                    4534 W Barlind Dr       $2,055   2,055
# 3    Fifth Ave opposite Van Braam St, Fifth Avenue,...       $1,650   1,650
# 4                            400 Denniston St, Unit 21       $1,710   1,710
# ..                                                 ...          ...     ...
# 985                                   West Mifflin, PA       $4,200     NaN
# 986  314 9th Street, Sharpsburg, Allegheny County, ...         $900     900
# 987        3821 Cabinet Way, Pittsburgh, PA 15201, USA       $1,800   1,800
# 988       5100 Alhambra Way, Pittsburgh, PA 15224, USA       $1,395   1,395
# 989            unnamed road, Pittsburgh, PA 15216, USA       $1,050     NaN
#
#     Bathroom Bedroom Rental Area Pets  AC Washer_Dryer Parking Dishwasher  \
# 0        NaN     NaN         NaN   No  No           No      No         No
# 1       1.5       3       1,080   Yes  No           No      No         No
# 2       1.5       3       1,264   Yes  No           No      No         No
# 3         1       1         788    No  No           No      No         No
# 4         1       1          NaN  Yes  No           No      No        Yes
# ..       ...     ...         ...  ...  ..          ...     ...        ...
# 985       1       3          NaN  Yes  No           No      No         No
# 986       1       1         500    No  No           No      No         No
# 987     1.5       2       1,188    No  No           No      No         No
# 988       1       3       1,200    No  No           No      No         No
# 989       1       1          NaN   No  No           No      No         No
#
#     Floors Roofdeck Storage Fireplace
# 0       No       No      No        No
# 1       No       No      No        No
# 2       No       No      No        No
# 3       No       No      No        No
# 4      Yes       No     Yes        No
# ..     ...      ...     ...       ...
# 985     No       No      No        No
# 986     No       No      No        No
# 987     No       No      No        No
# 988     No       No      No        No
# 989     No       No      No        No
#
# [990 rows x 16 columns]

# %%
pittsburg.isnull().sum()
# Out:
# URL               0
# Address           1
# Rental Price      0
# Deposit         704
# Bathroom         19
# Bedroom           1
# Rental Area     480
# Pets              0
# AC                0
# Washer_Dryer      0
# Parking           0
# Dishwasher        0
# Floors            0
# Roofdeck          0
# Storage           0
# Fireplace         0
# dtype: int64

# %%
# Cleaning dataframe , drop nan from area since its target variable
pittsburg = pittsburg[~pittsburg['Rental Area'].isna()]
pittsburg
# Out:
#                                                    URL  \
# 1    https://rentberry.com/houses/117569640-three-b...
# 2    https://rentberry.com/houses/116438309-three-b...
# 3    https://rentberry.com/apartments/116569483-one...
# 5    https://rentberry.com/apartments/97853640-one-...
# 6    https://rentberry.com/houses/116897875-six-br-...
# ..                                                 ...
# 982  https://rentberry.com/houses/116565337-four-br...
# 984  https://rentberry.com/apartments/115105155-thr...
# 986  https://rentberry.com/apartments/115338578-one...
# 987  https://rentberry.com/houses/116884588-two-br-...
# 988  https://rentberry.com/apartments/115059549-thr...
#
#                                                Address Rental Price Deposit  \
# 1                                       3107 Elroy Ave       $1,595   1,595
# 2                                    4534 W Barlind Dr       $2,055   2,055
# 3    Fifth Ave opposite Van Braam St, Fifth Avenue,...       $1,650   1,650
# 5                                       Pittsburgh, PA       $1,800     NaN
# 6    Pittsburgh Bruderhof House, 3400 Iowa Street, ...       $2,000   2,000
# ..                                                 ...          ...     ...
# 982  Milligan School, Vernon Avenue, Swissvale, All...       $1,500   1,500
# 984            Sixth Avenue, Pittsburgh, PA 15262, USA       $3,492     NaN
# 986  314 9th Street, Sharpsburg, Allegheny County, ...         $900     900
# 987        3821 Cabinet Way, Pittsburgh, PA 15201, USA       $1,800   1,800
# 988       5100 Alhambra Way, Pittsburgh, PA 15224, USA       $1,395   1,395
#
#     Bathroom Bedroom Rental Area Pets   AC Washer_Dryer Parking Dishwasher  \
# 1       1.5       3       1,080   Yes   No           No      No         No
# 2       1.5       3       1,264   Yes   No           No      No         No
# 3         1       1         788    No   No           No      No         No
# 5         1       1         700   Yes  Yes           No     Yes        Yes
# 6         2       6       2,447    No   No           No      No         No
# ..       ...     ...         ...  ...  ...          ...     ...        ...
# 982       2       4       1,480    No   No           No      No         No
# 984       1       3         102    No   No           No      No         No
# 986       1       1         500    No   No           No      No         No
# 987     1.5       2       1,188    No   No           No      No         No
# 988       1       3       1,200    No   No           No      No         No
#
#     Floors Roofdeck Storage Fireplace
# 1       No       No      No        No
# 2       No       No      No        No
# 3       No       No      No        No
# 5       No       No      No        No
# 6       No       No      No        No
# ..     ...      ...     ...       ...
# 982     No       No      No        No
# 984     No       No      No        No
# 986     No       No      No        No
# 987     No       No      No        No
# 988     No       No      No        No
#
# [510 rows x 16 columns]

# %%
pittsburg.insert(0, 'Sl_No', range(1, 1 + pittsburg.shape[0]))
pittsburg.insert(3, 'City', "Pittsburg")
pittsburg.insert(4, 'State', "PA")
pittsburg.insert(5, 'Country', "USA")

pittsburg
# Out:
#      Sl_No                                                URL  \
# 1        1  https://rentberry.com/houses/117569640-three-b...
# 2        2  https://rentberry.com/houses/116438309-three-b...
# 3        3  https://rentberry.com/apartments/116569483-one...
# 5        4  https://rentberry.com/apartments/97853640-one-...
# 6        5  https://rentberry.com/houses/116897875-six-br-...
# ..     ...                                                ...
# 982    506  https://rentberry.com/houses/116565337-four-br...
# 984    507  https://rentberry.com/apartments/115105155-thr...
# 986    508  https://rentberry.com/apartments/115338578-one...
# 987    509  https://rentberry.com/houses/116884588-two-br-...
# 988    510  https://rentberry.com/apartments/115059549-thr...
#
#                                                Address       City State  \
# 1                                       3107 Elroy Ave  Pittsburg    PA
# 2                                    4534 W Barlind Dr  Pittsburg    PA
# 3    Fifth Ave opposite Van Braam St, Fifth Avenue,...  Pittsburg    PA
# 5                                       Pittsburgh, PA  Pittsburg    PA
# 6    Pittsburgh Bruderhof House, 3400 Iowa Street, ...  Pittsburg    PA
# ..                                                 ...        ...   ...
# 982  Milligan School, Vernon Avenue, Swissvale, All...  Pittsburg    PA
# 984            Sixth Avenue, Pittsburgh, PA 15262, USA  Pittsburg    PA
# 986  314 9th Street, Sharpsburg, Allegheny County, ...  Pittsburg    PA
# 987        3821 Cabinet Way, Pittsburgh, PA 15201, USA  Pittsburg    PA
# 988       5100 Alhambra Way, Pittsburgh, PA 15224, USA  Pittsburg    PA
#
#     Country Rental Price Deposit Bathroom Bedroom Rental Area Pets   AC  \
# 1       USA       $1,595   1,595     1.5       3       1,080   Yes   No
# 2       USA       $2,055   2,055     1.5       3       1,264   Yes   No
# 3       USA       $1,650   1,650       1       1         788    No   No
# 5       USA       $1,800     NaN       1       1         700   Yes  Yes
# 6       USA       $2,000   2,000       2       6       2,447    No   No
# ..      ...          ...     ...      ...     ...         ...  ...  ...
# 982     USA       $1,500   1,500       2       4       1,480    No   No
# 984     USA       $3,492     NaN       1       3         102    No   No
# 986     USA         $900     900       1       1         500    No   No
# 987     USA       $1,800   1,800     1.5       2       1,188    No   No
# 988     USA       $1,395   1,395       1       3       1,200    No   No
#
#     Washer_Dryer Parking Dishwasher Floors Roofdeck Storage Fireplace
# 1             No      No         No     No       No      No        No
# 2             No      No         No     No       No      No        No
# 3             No      No         No     No       No      No        No
# 5             No     Yes        Yes     No       No      No        No
# 6             No      No         No     No       No      No        No
# ..           ...     ...        ...    ...      ...     ...       ...
# 982           No      No         No     No       No      No        No
# 984           No      No         No     No       No      No        No
# 986           No      No         No     No       No      No        No
# 987           No      No         No     No       No      No        No
# 988           No      No         No     No       No      No        No
#
# [510 rows x 20 columns]

# %% [markdown]
# # Creating Table

# %% [markdown]
# ### Table 1

# %%
Sl_no = pittsburg['Sl_No'].tolist()
Address = pittsburg['Address'].tolist()
city = pittsburg['City'].tolist()
state = pittsburg['State'].tolist()
country = pittsburg['Country'].tolist()
price = pittsburg['Rental Price'].tolist()
Deposit = pittsburg['Deposit'].tolist()

pittsburg_Table1 =pd.DataFrame({
    'Sl_No':Sl_no,
    'Address': Address,
    'City': city,
    'State': state,
    'Country' : country,
    'Price': price,
    'Deposit': Deposit
})
pittsburg_Table1


pittsburg_Table1.to_csv('pittsburg_Table1.csv', index=False)

# %% [markdown]
# ### Table 2

# %%
Sl_no = pittsburg['Sl_No'].tolist()
Beds = pittsburg['Bedroom'].tolist()
Baths = pittsburg['Bathroom'].tolist()
R_area = pittsburg['Rental Area'].tolist()
pets = pittsburg['Pets'].tolist()

pittsburg_Table2 =pd.DataFrame({
    'Sl_No':Sl_no,
    'Bedrooms': Beds,
    'Bathrooms': Baths,
    'Area' : R_area,
    'Pets Allowed': pets,
})
pittsburg_Table2


pittsburg_Table2.to_csv('pittsburg_Table2.csv', index=False)

# %% [markdown]
# ### Table 3

# %%
Sl_no = pittsburg['Sl_No'].tolist()
AC = pittsburg['AC'].tolist()
washer = pittsburg['Washer_Dryer'].tolist()
Parking = pittsburg['Parking'].tolist()
Dishwasher = pittsburg['Dishwasher'].tolist()
floor = pittsburg['Floors'].tolist()
roof = pittsburg['Roofdeck'].tolist()
storage = pittsburg['Storage'].tolist()
fireplace = pittsburg['Fireplace'].tolist()


pittsburg_Table3 =pd.DataFrame({
    'Sl_No':Sl_no,
    'Washer/Dryer': washer,
    'AC': AC,
    'Parking' : Parking,
    'Fireplace': fireplace,
    'Dishwasher': Dishwasher,
    'Hardwood floors': floor,
    'Roofdeck': roof,
    'storage': storage
})

pittsburg_Table3
# Out:
#      Sl_No Washer/Dryer   AC Parking Fireplace Dishwasher Hardwood floors  \
# 0        1           No   No      No        No         No              No
# 1        2           No   No      No        No         No              No
# 2        3           No   No      No        No         No              No
# 3        4           No  Yes     Yes        No        Yes              No
# 4        5           No   No      No        No         No              No
# ..     ...          ...  ...     ...       ...        ...             ...
# 505    506           No   No      No        No         No              No
# 506    507           No   No      No        No         No              No
# 507    508           No   No      No        No         No              No
# 508    509           No   No      No        No         No              No
# 509    510           No   No      No        No         No              No
#
#     Roofdeck storage
# 0         No      No
# 1         No      No
# 2         No      No
# 3         No      No
# 4         No      No
# ..       ...     ...
# 505       No      No
# 506       No      No
# 507       No      No
# 508       No      No
# 509       No      No
#
# [510 rows x 9 columns]

# %%
pittsburg_Table3.to_csv('pittsburg_Table3.csv', index=False)

# %%
pittsburg.to_csv('pittsburg.csv', index = False)

# %% [markdown]
# ### Vancouver, BC, Canada

# %%
driver = webdriver.Chrome()
driver.get('https://rentberry.com/ca/apartments/s/vancouver-bc-canada')
time.sleep(2)

# %%
va_URL = []
va_Price = []

# %%
start=0
end=5


for page in range(start,end):
    url_tags= driver.find_elements(By.XPATH,'//a[@class="property-card-bottom-address__text link-ghost font-xs one-line-string"]')
    price = driver.find_elements(By.XPATH,'//rb-property-card-bottom[@class="property-card__bottom"]/div/div/rb-property-card-price/div/p')
    
    for _ in range(200):
        driver.execute_script("window.scrollBy(0,200)")
        
    for t in url_tags:
        va_URL.append(t.get_attribute('href'))
    for a in price:
        va_Price.append(a.text)
        
    next_page = driver.find_element(By.XPATH,'//span[@class="pagination-arrow-next"]')
    next_page.click()
    

    time.sleep(5)

# %%
va_Pets = []
va_Area = []
va_Address = []
va_Deposit = []
va_Beds = []
va_Bathroom = []
va_Washer_Dryer =[]
va_AC = []
va_Parking=[]
va_Fireplace=[]
va_Dishwasher=[]
va_Floors=[]
va_Roofdeck=[]
va_Storage=[]

# %%
for t in va_URL:
    driver.get(t)
    time.sleep(5)
    
    try:
        add = driver.find_element(By.XPATH,'/html/body/rb-core/div/rb-property/div/div[1]/rb-property-main-info/section/div/div/rb-property-data/div/h4/span/span')
        va_Address.append(add.text)
    except NoSuchElementException:
        va_Address.append('-')
        
    try:
        bed = driver.find_element(By.XPATH,'/html/body/rb-core/div/rb-property/div/div[1]/rb-property-main-info/rb-apartment-card-swiper/div/div[3]/rb-apartment-internals/section/div[1]/div[2]/span[1]')
        va_Beds.append(bed.text)
    except NoSuchElementException:
        va_Beds.append('-') 
        
    try:
        bath = driver.find_element(By.XPATH,'/html/body/rb-core/div/rb-property/div/div[1]/rb-property-main-info/rb-apartment-card-swiper/div/div[3]/rb-apartment-internals/section/div[2]/div[2]/span[1]')
        va_Bathroom.append(bath.text)
    except NoSuchElementException:
        va_Bathroom.append('-') 
        
    try:
        sqft = driver.find_element(By.XPATH,'/html/body/rb-core/div/rb-property/div/div[1]/rb-property-main-info/rb-apartment-card-swiper/div/div[3]/rb-apartment-internals/section/div[3]/div[2]/span[1]')
        va_Area.append(sqft.text.replace(' \nSq Ft',''))
    except NoSuchElementException:
        va_Area.append('-')
        
    try:
        pet = driver.find_element(By.XPATH,'/html/body/rb-core/div/rb-property/div/div[1]/rb-property-main-info/section/div/div/rb-property-facilities/section/div[4]')
        va_Pets.append(pet.text.replace("\n", " "))
    except NoSuchElementException:
        va_Pets.append('-')
        
    try:
        adv = driver.find_element(By.XPATH,'/html/body/rb-core/div/rb-property/div/div[2]/div/rb-apply-block/div/div/rb-button-square/button/span/span[2]/span[1]')
        va_Deposit.append(adv.text.replace("Apply for $",''))
    except NoSuchElementException:
        va_Deposit.append('-')
        
    try:
        was = driver.find_element(By.XPATH, "//*[contains(@class,'icon washerUnit')]")
        va_Washer_Dryer.append('Yes')
    except NoSuchElementException:
        va_Washer_Dryer.append('No')   
        
    try:
        ac = driver.find_element(By.XPATH,"//*[contains(@class,'airConditioning icon')]")
        va_AC.append('Yes')
    except NoSuchElementException:
        va_AC.append('No')
       
    try:
        park = driver.find_element(By.XPATH,"//*[contains(@class,'icon parking')]")
        va_Parking.append('Yes')
    except NoSuchElementException:
        va_Parking.append('No') 

    try:
        dish = driver.find_element(By.XPATH,"//*[contains(@class,'dishwasher icon')]")
        va_Dishwasher.append('Yes')
    except NoSuchElementException: 
        va_Dishwasher.append('No')
    try:
        hard = driver.find_element(By.XPATH,"//*[contains(@class,'hardwoodFloors icon')]")
        va_Floors.append('Yes')
    except NoSuchElementException:
        va_Floors.append('No')
        
    try:
        roof = driver.find_element(By.XPATH,"//*[contains(@class,'icon roofDeck')]")
        va_Roofdeck.append('Yes')  
    except NoSuchElementException:
        va_Roofdeck.append('No')
        
    try:
        store = driver.find_element(By.XPATH, "//*[contains(@class,'icon storage')]")
        va_Storage.append('Yes')
    except NoSuchElementException: 
        va_Storage.append('No')
                    
    try:
        fire = driver.find_element(By.XPATH, "//*[contains(@class,'fireplace icon')]")
        va_Fireplace.append('Yes')
    except NoSuchElementException:  
        va_Fireplace.append('No')

# %%
print(len(va_URL), len(va_Price))
# Out:
# 374 374

# %%
print(len(va_URL), len(va_Price),len(va_Address),len(va_Bathroom),len(va_Beds),len(va_Area),len(va_Pets),len(va_Deposit),len(va_AC),len(va_Washer_Dryer),len(va_Parking),len(va_Dishwasher),len(va_Floors),len(va_Roofdeck),len(va_Storage), len(va_Fireplace))
# Out:
# 374 374 374 374 374 374 374 374 374 374 374 374 374 374 374 374

# %%
vancouver = pd.DataFrame({'URL': va_URL, 'Price':va_Price, 'Area': va_Area,'Bedroom':va_Beds,'Bathrooms': va_Bathroom,'Pets':va_Pets,'deposit':va_Deposit,'address':va_Address,'Washer':va_Washer_Dryer,'AC':va_AC,'Parking':va_Parking,'Dishwasher':va_Dishwasher, 'Storage':va_Storage,'Fireplace':va_Fireplace,'Roofdeck': va_Roofdeck, 'HardwoodFloors':va_Floors})
vancouver
# Out:
#                                                    URL    Price    Area  \
# 0    https://rentberry.com/ca/houses/96265544-one-b...   $4,097    450
# 1    https://rentberry.com/ca/apartments/96527586-o...   $5,284    360
# 2    https://rentberry.com/ca/apartments/95680490-t...   $7,505    900
# 3    https://rentberry.com/ca/apartments/109143205-...   $6,242       -
# 4    https://rentberry.com/ca/houses/110118969-five...   $1,075       -
# ..                                                 ...      ...     ...
# 369  https://rentberry.com/ca/houses/95818258-three...   $9,305  1,000
# 370  https://rentberry.com/ca/houses/96748040-one-b...   $2,680       -
# 371  https://rentberry.com/ca/houses/96819063-four-...  $23,091  5,000
# 372  https://rentberry.com/ca/houses/96083171-two-b...   $3,753       -
# 373  https://rentberry.com/ca/houses/109138623-thre...  $17,883       -
#
#     Bedroom Bathrooms             Pets deposit  \
# 0        1         1   No pets Allowed       -
# 1        1         1   No pets Allowed       -
# 2        2         2      Dogs Allowed       -
# 3        1         1      Cats Allowed       -
# 4        5         2                 -       -
# ..      ...       ...              ...     ...
# 369      3         3   No pets Allowed       -
# 370      1         1                 -       -
# 371      4         5      Dogs Allowed       -
# 372      2         2                 -       -
# 373      3         3      Cats Allowed       -
#
#                                                address Washer   AC Parking  \
# 0    Reality Church Vancouver, 808 East 19th Avenue...     No   No     Yes
# 1    Grandview-Woodland, Vancouver, BC V5L 2H6, Canada     No  Yes     Yes
# 2                        Vancouver, BC V6B 0G1, Canada     No  Yes     Yes
# 3              Yaletown, Vancouver, BC V6B 6L6, Canada     No   No      No
# 4          Vancouver, Kensington-Cedar Cottage, BC, CA     No   No      No
# ..                                                 ...    ...  ...     ...
# 369                      Vancouver, BC V5P 1S3, Canada     No  Yes     Yes
# 370  Kensington-Cedar Cottage, Vancouver, BC V5V 1C...     No   No     Yes
# 371       Arbutus Ridge, Vancouver, BC V6N 3Y7, Canada     No  Yes     Yes
# 372        South Cambie, Vancouver, BC V5Y 2E7, Canada     No   No     Yes
# 373       Hastings East, Vancouver, BC V5K 2C6, Canada     No  Yes     Yes
#
#     Dishwasher Storage Fireplace Roofdeck HardwoodFloors
# 0          Yes      No        No       No             No
# 1           No      No        No       No             No
# 2          Yes      No        No       No             No
# 3          Yes      No        No       No             No
# 4           No      No        No       No             No
# ..         ...     ...       ...      ...            ...
# 369        Yes      No       Yes       No             No
# 370         No      No        No       No             No
# 371        Yes      No       Yes       No             No
# 372        Yes      No        No       No             No
# 373         No      No       Yes       No             No
#
# [374 rows x 16 columns]

# %%
rent1 = pd.concat([miami, jersey, lasvegas, irvine, nashville, pittsburg, sanfrancisco, sanjose, toronto, vancouver],axis=0)
rent1
# Out:
#                                                    URL    Price    Area  \
# 0    https://rentberry.com/apartments/115918379-thr...   $7,900  1,526
# 1    https://rentberry.com/apartments/96699282-one-...   $4,560    431
# 2    https://rentberry.com/houses/97303817-five-br-...  $37,770       -
# 3    https://rentberry.com/apartments/109130572-two...   $6,840  1,097
# 4    https://rentberry.com/apartments/114055668-one...   $1,875    349
# ..                                                 ...      ...     ...
# 369  https://rentberry.com/ca/houses/95818258-three...   $9,305  1,000
# 370  https://rentberry.com/ca/houses/96748040-one-b...   $2,680       -
# 371  https://rentberry.com/ca/houses/96819063-four-...  $23,091  5,000
# 372  https://rentberry.com/ca/houses/96083171-two-b...   $3,753       -
# 373  https://rentberry.com/ca/houses/109138623-thre...  $17,883       -
#
#     Bedroom Bathrooms             Pets deposit  \
# 0        3         3      Dogs Allowed   7,900
# 1        1         1   No pets Allowed       -
# 2        5         4      Cats Allowed       -
# 3        2         2   No pets Allowed       -
# 4        1         1                 -   1,875
# ..      ...       ...              ...     ...
# 369      3         3   No pets Allowed       -
# 370      1         1                 -       -
# 371      4         5      Dogs Allowed       -
# 372      2         2                 -       -
# 373      3         3      Cats Allowed       -
#
#                                                address Washer   AC Parking  \
# 0                            3131 Northeast 7th Avenue     No   No      No
# 1                                     Coral Gables, FL     No  Yes     Yes
# 2                                            Miami, FL     No  Yes     Yes
# 3                                            Miami, FL     No  Yes      No
# 4    1971 Bay Drive, Isle of Normandy, Miami Beach,...     No   No      No
# ..                                                 ...    ...  ...     ...
# 369                      Vancouver, BC V5P 1S3, Canada     No  Yes     Yes
# 370  Kensington-Cedar Cottage, Vancouver, BC V5V 1C...     No   No     Yes
# 371       Arbutus Ridge, Vancouver, BC V6N 3Y7, Canada     No  Yes     Yes
# 372        South Cambie, Vancouver, BC V5Y 2E7, Canada     No   No     Yes
# 373       Hastings East, Vancouver, BC V5K 2C6, Canada     No  Yes     Yes
#
#     Dishwasher Storage Fireplace Roofdeck HardwoodFloors
# 0           No      No        No       No             No
# 1           No      No       Yes       No             No
# 2          Yes      No       Yes       No             No
# 3          Yes      No        No       No             No
# 4           No      No        No       No             No
# ..         ...     ...       ...      ...            ...
# 369        Yes      No       Yes       No             No
# 370         No      No        No       No             No
# 371        Yes      No       Yes       No             No
# 372        Yes      No        No       No             No
# 373         No      No       Yes       No             No
#
# [4878 rows x 16 columns]

# %%
rent1 = pd.concat([Austin, Bf_ny, dallas, miami, jersey, lasvegas, irvine, nashville, pittsburg, sanfrancisco, sanjose, toronto, vancouver],axis=0)
rent1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17584\4230902197.py in <module>
# ----> 1 rent1 = pd.concat([Austin, Bf_ny, dallas, miami, jersey, lasvegas, irvine, nashville, pittsburg, sanfrancisco, sanjose, toronto, vancouver],axis=0)
#       2 rent1
#
# NameError: name 'Austin' is not defined

# %%
rent1.to_csv("rent.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9900\2031170066.py in <module>
# ----> 1 rent1.to_csv("rent.csv")
#
# NameError: name 'rent1' is not defined
